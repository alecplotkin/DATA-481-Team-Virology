# %%
import pandas as pd

# %%
# Define the file path
distances_file_path = "/Users/praveenpuviindran/Documents/Current Course Material/DATA481S25/Virology-DATA481/average_gene_distance_matrix.csv"  # Replace with the correct path

# Load the CSV file into a DataFrame
df_distances = pd.read_csv(distances_file_path)

df_distances
# Out:
#    Unnamed: 0             K1            K14            K15             K2  \
# 0          K1       0.000000  128745.833333  131770.733333   17453.333333
# 1         K14  128745.833333       0.000000    3024.900000  111292.500000
# 2         K15  131770.733333    3024.900000       0.000000  114317.400000
# 3          K2   17453.333333  111292.500000  114317.400000       0.000000
# 4          K3   18812.666667  109933.166667  112958.066667    1359.333333
# ..        ...            ...            ...            ...            ...
# 59       Orf8   10110.333333  118635.500000  121660.400000    7343.000000
# 60       Orf9   13429.333333  115316.500000  118341.400000    4024.000000
# 61      vIRF1   83968.208333   44777.625000   47802.525000   66514.875000
# 62      vIRF2   92249.583333   36496.250000   39521.150000   74796.250000
# 63      vIRF4   86355.583333   42390.250000   45415.150000   68902.250000
#
#                K3             K4             K5             K7           LANA  \
# ...
