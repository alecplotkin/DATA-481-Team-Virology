# %%
# Import necessary libraries
import pandas as pd

# %%
# Define the file path
modeling_file_path = "/Users/praveenpuviindran/Documents/Current Course Material/DATA481S25/Virology-DATA481/premodeling_KSV_gex.csv"  # Replace with the correct path

# Load the CSV file into a DataFrame
modeling_df = pd.read_csv(modeling_file_path)

# Rename the first two columns
modeling_df.rename(columns={modeling_df.columns[0]: "Cluster", modeling_df.columns[1]: "SampleID"}, inplace=True)

# Set 'SampleID' as the index
modeling_df.set_index('SampleID', inplace=True)

# Display the updated DataFrame
modeling_df
# Out:
#           Cluster  K1_133PP1.TRUE  K1_348PP1.TRUE  K1_622PP1.TRUE  \
# SampleID
# 180.0         1.0       -0.594482       -1.390993       -2.262487
# 220.0         1.0       -0.594482       -1.390993       -2.262487
# 225.0         1.0        0.590534       -0.205977       -1.077470
# 316.0         2.0       -0.594482       -1.390993       -2.262487
# 541.0         1.0        2.336119       -1.390993       -2.262487
# 1167.0        2.0       -0.594482       -1.390993       -2.262487
# 1338.0        2.0       -0.594482       -1.390993       -2.262487
# 1347.0        1.0       -0.594482       -1.390993       -2.262487
# 1367.0        2.0       -0.594482       -1.390993       -2.262487
# 1461.0        2.0       -0.594482       20.237945       -2.262487
# 1835.0        2.0        2.839460       -1.390993       10.841456
# 3392.0        2.0       -0.594482       -1.390993       -2.262487
# 3450.0        1.0       -0.594482       -1.390993       -2.262487
# ...

# %%
# Extract the 'Cluster' column as a vector (Series)
cluster_vector = modeling_df["Cluster"]

# Display the vector
print(cluster_vector)
# Out:
# SampleID
# 180.0     1.0
# 220.0     1.0
# 225.0     1.0
# 316.0     2.0
# 541.0     1.0
# 1167.0    2.0
# 1338.0    2.0
# 1347.0    1.0
# 1367.0    2.0
# 1461.0    2.0
# 1835.0    2.0
# 3392.0    2.0
# 3450.0    1.0
# 3588.0    1.0
# 4337.0    2.0
# 4647.0    1.0
# 4750.0    1.0
# 4983.0    1.0
# 5030.0    2.0
# 5098.0    1.0
# 5130.0    2.0
# 5267.0    1.0
# 5386.0    1.0
# 5557.0    1.0
# 5720.0    1.0
# 6039.0    2.0
# 6268.0    2.0
# 6725.0    2.0
# 6814.0    2.0
# 7109.0    1.0
# 8064.0    2.0
# 8670.0    2.0
# 9161.0    1.0
# 9401.0    1.0
# 9926.0    1.0
# NaN       NaN
# 9953.0    NaN
# Name: Cluster, dtype: float64
