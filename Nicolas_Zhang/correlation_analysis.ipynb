# %% [markdown]
# # Distance correlation Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns

distance_matrix = pd.read_csv('D_20250304.csv', index_col=0)
correlation_matrix = pd.read_csv('R_20250304.csv')

# %%
distance_matrix
# Out:
#                       K1_133PP1.TRUE  K1_348PP1.TRUE  K1_622PP1.TRUE  \
# K1_133PP1.TRUE                   0.0           215.0           489.0
# K1_348PP1.TRUE                 215.0             0.0           274.0
# K1_622PP1.TRUE                 489.0           274.0             0.0
# K3_18883PP1.TRUE             18750.0         18535.0         18261.0
# K3_19081PP1.TRUE             18948.0         18733.0         18459.0
# ...                              ...             ...             ...
# K15_131117PP2.TRUE          130984.0        130769.0        130495.0
# K15_131117.5PP2.TRUE        130984.5        130769.5        130495.5
# K15_131458PP2.TRUE          131325.0        131110.0        130836.0
# K15_136250.5PP2.TRUE        136117.5        135902.5        135628.5
# K2_17821PP1.TRUE             17688.0         17473.0         17199.0
#
#                       K3_18883PP1.TRUE  K3_19081PP1.TRUE  K3_19577PP1.TRUE  \
# ...

# %%
correlation_matrix
# Out:
#                Unnamed: 0  K1_133PP1.TRUE  K1_348PP1.TRUE  K1_622PP1.TRUE  \
# 0          K1_133PP1.TRUE        1.000000        0.290987        0.855912
# 1          K1_348PP1.TRUE        0.290987        1.000000        0.407097
# 2          K1_622PP1.TRUE        0.855912        0.407097        1.000000
# 3        K3_18883PP1.TRUE       -0.094408        0.352955        0.024926
# 4        K3_19081PP1.TRUE        0.042717        0.191772        0.144906
# ..                    ...             ...             ...             ...
# 221    K15_131117PP2.TRUE        0.205415        0.254638        0.175108
# 222  K15_131117.5PP2.TRUE        0.082882       -0.008462       -0.032619
# 223    K15_131458PP2.TRUE        0.112570        0.083513        0.112332
# 224  K15_136250.5PP2.TRUE       -0.238145       -0.206002       -0.254397
# 225      K2_17821PP1.TRUE        0.159411        0.316609        0.173599
#
#      K3_18883PP1.TRUE  K3_19081PP1.TRUE  K3_19577PP1.TRUE  \
# ...

# %%
sns.heatmap(distance_matrix, cmap='viridis')
# Out:
# <Axes: >

# %%
correlation_matrix.set_index(correlation_matrix.columns[0], inplace=True)
sns.heatmap(correlation_matrix, cmap='viridis')
# Out:
# <Axes: ylabel='Unnamed: 0'>

# %%
import matplotlib.pyplot as plt
